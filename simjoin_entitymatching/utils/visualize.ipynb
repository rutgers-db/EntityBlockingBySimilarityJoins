# %%
import visualize_helper as vis

# tp cosine
vis.show_semantic_distribution(False)

# %%
import visualize_helper as vis

vis.show_synatic_distribution()

# %%
# fp cosine
vis.show_semantic_distribution(True)

# %%
# tp first proba
vis.show_first_proba_distribution(False)

# %%
# fp first proba
vis.show_first_proba_distribution(True)

# %%
import visualize_helper as vis

# tp diff proba
vis.show_second_proba_distribution(False)

# fp diff proba
vis.show_second_proba_distribution(True)

# %%
import visualize_helper as vis

# tp diff proba
vis.show_diff_proba_distribution(False, True)

# fp diff proba
vis.show_diff_proba_distribution(True, True)

# %%
import visualize_helper as vis

# tp diff proba
vis.show_relation_first_proba_semantic(False)

# fp diff proba
vis.show_relation_first_proba_semantic(True)
